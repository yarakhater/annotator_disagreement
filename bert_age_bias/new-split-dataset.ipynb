# %%
import sys
sys.path.append("..")

from sklearn.model_selection import train_test_split
import pandas as pd
import torch
from sklearn.model_selection import GroupShuffleSplit 
import matplotlib.pyplot as plt
import nltk
from torch import optim
from nltk.corpus import stopwords
from models import bert
from transformers import BertTokenizer, BertForSequenceClassification, BertPreTrainedModel, BertModel
import json
from torch.utils.data import DataLoader
from ray import tune
from ray.air import Checkpoint, session
from ray.tune.schedulers import ASHAScheduler
from functools import partial

# %%
train_df = pd.read_csv('../data/train_older_adult_annotations.csv',delimiter=',', encoding='latin-1')
test_df = pd.read_csv('../data/test_annotations.csv', delimiter=',')
# df = pd.concat([test_df, train_df])

# age_anxiety_df = pd.read_csv('../data/age_anxiety_full_responses.csv', delimiter=',')
# age_experience_df = pd.read_csv('../data/age_experience_responses.csv', delimiter=',')
demographics_df = pd.read_csv('../data/demographics_responses.csv', delimiter=',')
anxiety_score_df = pd.read_csv('../data/respondent_anxiety_table.csv', delimiter=',')

anxiety_score_df = anxiety_score_df[anxiety_score_df['respondent_id'].isin(train_df['respondent_id'])]
demographics_df = demographics_df[demographics_df['respondent_id'].isin(train_df['respondent_id'])]

# df1 = pd.merge(demographics_df, anxiety_score_df, on='respondent_id')
# merged_df = pd.merge(df, df1, on='respondent_id')

sentiment_labels = ['Very negative','Somewhat negative','Neutral','Somewhat positive','Very positive']
total_annotator_ids = train_df['respondent_id'].unique().tolist()

id2label = {index: row for (index, row) in enumerate(sentiment_labels)} 
label2id = {row: index for (index, row) in enumerate(sentiment_labels)}

id2annotator = {index: row for (index, row) in enumerate(total_annotator_ids)}
annotator2id = {row: index for (index, row) in enumerate(total_annotator_ids)}

train_df["annotation"] = train_df["annotation"].map(label2id)
train_df["respondent_id"] = train_df["respondent_id"].map(annotator2id)


test_df["annotation"] = test_df["annotation"].map(label2id)
test_df["respondent_id"] = test_df["respondent_id"].map(annotator2id)

anxiety_score_df["respondent_id"] = anxiety_score_df["respondent_id"].map(annotator2id)
demographics_df["respondent_id"] = demographics_df["respondent_id"].map(annotator2id)



train_df.rename(columns = {'respondent_id':'annotator_id', 'unit_text':'text'}, inplace = True)
test_df.rename(columns = {'respondent_id':'annotator_id', 'unit_text':'text'}, inplace = True)

train_df['original_index'] = train_df.index
test_df['original_index'] = test_df.index


train_agr = train_df.groupby('unit_id')['annotation'].nunique().reset_index()
train_agr.columns = ['unit_id', 'unique_annotations']
train_df = train_df.merge(train_agr, on='unit_id')
train_df['disagreement'] = train_df['unique_annotations'] > 1

test_agr = test_df.groupby('unit_id')['annotation'].nunique().reset_index()
test_agr.columns = ['unit_id', 'unique_annotations']
test_df = test_df.merge(test_agr, on='unit_id')
test_df['disagreement'] = test_df['unique_annotations'] > 1


# Sort the DataFrame back based on the original index
train_df.sort_values(by='original_index', inplace=True)
test_df.sort_values(by='original_index', inplace=True)

# Drop the additional column used for sorting
train_df.drop(columns='original_index', inplace=True)
test_df.drop(columns='original_index', inplace=True)


# grouped = merged_df.groupby('unit_id')['annotation'].nunique().reset_index()
# grouped.columns = ['unit_id', 'unique_annotations']
# merged_df = merged_df.merge(grouped, on='unit_id')
# merged_df['disagreement'] = merged_df['unique_annotations'] > 1

# %%
train_df.to_csv('train_new_agr.csv',index=False)
test_df.to_csv('test_new_agr.csv',index=False)

# order anxiety_score_df and demographics_df by respondent_id
anxiety_score_df = anxiety_score_df.sort_values(by=['respondent_id'])
demographics_df = demographics_df.sort_values(by=['respondent_id'])
anxiety_score_df.to_csv('anxiety_score.csv',index=False)
demographics_df.to_csv('demographics.csv',index=False)

# %%
len(train_df[train_df["disagreement"]==True]["unit_id"].unique())
# Out:
# 13179

# %%
len(test_df)
# Out:
# 1419

# %%
len(test_df["annotator_id"].unique())
# Out:
# 878

# %%
demographics_df["respondent_id"]
# Out:
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4
#         ...
# 1478    1476
# 1479    1477
# 1480    1478
# 1481    1479
# 1482    1480
# Name: respondent_id, Length: 1481, dtype: int64

# %%
id2annotator[105]
# Out:
# 'R_3fP575Tw6XFk2ZQ'

# %%
id2annotator
# Out:
# {0: 'R_1I5depz6ASpP2YF',
#  1: 'R_27sAwU5dMyvKR8P',
#  2: 'R_2vYT6suV4FhYAHk',
#  3: 'R_2BnzNYeKLHABEei',
#  4: 'R_A6vEunsl5EoPDpv',
#  5: 'R_3fJfPSVmVDNnwSV',
#  6: 'R_2WBVl0niLFn9elJ',
#  7: 'R_3r05gWBZNv3oDVT',
#  8: 'R_2RVSQMPKzVgYL6h',
#  9: 'R_pyBFvQ1UFMyVIK5',
#  10: 'R_1nOZMXdItb3ndyg',
#  11: 'R_2DYyJkrMpwLQa1R',
#  12: 'R_1DNgjAY3UEWZ0cY',
#  13: 'R_um1uN1qA26hCGWt',
#  14: 'R_3iFkZsqgPlEdip0',
#  15: 'R_3O2oZt1CSyajAp3',
#  16: 'R_3hhxJZ7lbzmKDRa',
#  17: 'R_yryBGY1HcMufVDP',
#  18: 'R_1Q583LMM1Y0MnTQ',
#  19: 'R_ROat0DEbUWO4USZ',
#  20: 'R_2dYEKmjPPDzHdWK',
#  21: 'R_88rUOre21x1uFzj',
#  22: 'R_2v8rV7Ca1iS18to',
#  23: 'R_0H7jeIMm5pV11fz',
#  24: 'R_1Q5e81duDXvXxKj',
#  25: 'R_1d0KM7jMHnInzID',
#  26: 'R_6Gpg9oK8GbVKrfz',
#  27: 'R_2P09pxi3f97SjmC',
#  28: 'R_2eWGOh7ayjbChpo',
#  29: 'R_2ZJilZyKgHWlt5P',
#  30: 'R_1laGR7wF0PmMJcj',
#  31: 'R_3NCJr1AtKOCIlQA',
#  32: 'R_32MhJB47fCWq7KD',
#  33: 'R_V23HpjP1cmZge8V',
#  34: 'R_33BfNBilcVzC8U2',
#  35: 'R_2Pcy0501eyoVd8a',
#  36: 'R_1gd12wOeCAzyYmG',
#  37: 'R_2CB8bFwIiD7UPAl',
#  38: 'R_1Cg5DUX77xWG2ND',
#  39: 'R_3n5Z2koSHvfL0bV',
#  40: 'R_2wGeAUpcuEs8WaN',
#  41: 'R_1PRCfToAbB5NOji',
#  42: 'R_ywDvzbV4XAoXdT3',
#  43: 'R_23fqCP2xyvxhvHo',
#  44: 'R_3ksNpGVv6TeL03H',
#  45: 'R_1IFz89QfBk53UaJ',
#  46: 'R_2S8ozDhmRiAzwHg',
#  47: 'R_3I00O7tcFvXRNKJ',
#  48: 'R_uf86EkHpgoCjUlP',
#  49: 'R_9pHIDyklhb7sTHX',
#  50: 'R_3e2JDNRfHnCqUUK',
#  51: 'R_21hdFfkYi1EaoMU',
#  52: 'R_ZKKITeMMcbHiONb',
#  53: 'R_1qfE8jBRwGoQYB4',
#  54: 'R_2S6pyBUxlKXIvH5',
#  55: 'R_1qWBVU43ADdBaUa',
#  56: 'R_2agiE1FoB0vSu3u',
#  57: 'R_0kbvQNjFLM3ly4F',
#  58: 'R_Qd0rzCdcuKT8AwN',
#  59: 'R_Ab7lDskBQrDk2D7',
#  60: 'R_3CWwpEOhXg9mfpQ',
#  61: 'R_r7QvEEt34le4JFL',
#  62: 'R_2yjgCV6xNUsmoGp',
#  63: 'R_1N4l064VFkVK7jl',
#  64: 'R_1DYyN29PYh5nIbi',
#  65: 'R_2qqtD5jRdF3OdML',
#  66: 'R_2U3NWy95703kp6w',
#  67: 'R_Ti8WWLju9slkMWR',
#  68: 'R_2PBE5RT6oi1FHAC',
#  69: 'R_2ykd9U8GslKbMXw',
#  70: 'R_1o20dXDPgsl7KBH',
#  71: 'R_10TA90gzTHOB5al',
#  72: 'R_DSLaYLs6eRb1Ihr',
#  73: 'R_3hxT6zUG7YN7ToR',
#  74: 'R_XU3TEb2MVRgDmE1',
#  75: 'R_djrXeKvk3Yyj8LD',
#  76: 'R_2s4jqfM06qG2a8y',
#  77: 'R_2YWy0fi18vyjykm',
#  78: 'R_12ukZG5D6hWTEcJ',
#  79: 'R_3KMBbuiM55IrkpY',
#  80: 'R_oYsCMz8oHw1bvDb',
#  81: 'R_Ckpav25wXJuefDP',
#  82: 'R_3smKy3k5ZFewqpZ',
#  83: 'R_2xDFZIRgOnGLuz5',
#  84: 'R_264NBWeFENs9tQd',
#  85: 'R_3hlTH8Q3bBro5ki',
#  86: 'R_1i22eOWu41FbHwy',
#  87: 'R_2AFFwgHfnNWrfdP',
#  88: 'R_1DMV4h1mtSOmAZu',
#  89: 'R_2zShH7VGk0GGR66',
#  90: 'R_2wAcy90mVKvEczM',
#  91: 'R_1DqX9JgqYpjqteY',
#  92: 'R_2BgkeCD28gLORj2',
#  93: 'R_2cu8eFy8oG40zjl',
#  94: 'R_2PkghjHS7zr8mHt',
#  95: 'R_1oAAYv0fwaiktmL',
#  96: 'R_3hhlankvD2Zhzyi',
#  97: 'R_2xFweGhJLAzq67w',
#  98: 'R_2X4pWFHdnuwhjGl',
#  99: 'R_1Lh4K1EjpnRs3iE',
#  100: 'R_1BNzNd3avdtX59n',
#  101: 'R_PBPJ3yIr9mYT4ul',
#  102: 'R_2VHZB37iIOcNPPd',
#  103: 'R_SZyRPzLJzog9a9z',
#  104: 'R_3D5Uhf7xPgqNAd4',
#  105: 'R_3fP575Tw6XFk2ZQ',
#  106: 'R_1KpwrwuYFht9QlF',
#  107: 'R_1li4lD3uv2VDZUW',
#  108: 'R_UsBspFZ1keMn25H',
#  109: 'R_xaozzMeqeedTytb',
#  110: 'R_2qyqPAm16Pb5kVe',
#  111: 'R_3noNQjsySx9r78f',
#  112: 'R_SAXGm8X0fNaBokx',
#  113: 'R_AoYsJoylwmh036x',
#  114: 'R_25LRQB6uCd0niOP',
#  115: 'R_1IJYQ0FxrzNyXgs',
#  116: 'R_1IGKuHpqNgRsv3A',
#  117: 'R_WATTDuUCKWZ7kGt',
#  118: 'R_3Ppi5OxmkRn4BHO',
#  119: 'R_1NwAxruExoyiPmh',
#  120: 'R_2vYZYBg3WNdSun8',
#  121: 'R_3iVlRj2JplVpipu',
#  122: 'R_1N2Gk2S31EYcd6V',
#  123: 'R_WiJQOfnJDQV40Kt',
#  124: 'R_8jlLpim52ADcdvH',
#  125: 'R_1HUWB9OUpoLsb85',
#  126: 'R_2qxFYuPq5uhWZc2',
#  127: 'R_6thuPBQlqPBThNn',
#  128: 'R_sTBsVGLwabVrOEx',
#  129: 'R_1rxAD567hiwFbjA',
#  130: 'R_1OYLVNrLGMExf0b',
#  131: 'R_r9o18eVBHlLRU2J',
#  132: 'R_2as4UmC9fyw0RRl',
#  133: 'R_1XsXDa7xidkxEtP',
#  134: 'R_2ZEwAyRpJV4TYu8',
#  135: 'R_2R9xpsSEZyV8lde',
#  136: 'R_3imYcWlmQnstnAD',
#  137: 'R_3QGaeiPkGvOtwA2',
#  138: 'R_szYTLzDg5nNHFrH',
#  139: 'R_3HCgz2GFveFwgI9',
#  140: 'R_0Du2zxNGDtmSP3r',
#  141: 'R_3s7C7lCMEKWloJg',
#  142: 'R_2BsNEOv9GvYQTB0',
#  143: 'R_268sez2RlTMqX3y',
#  144: 'R_qwmnzb4bPmEmXxT',
#  145: 'R_1ihuDojJrcpXLNg',
#  146: 'R_1LAqRAUIPhGnVl3',
#  147: 'R_1dyq5MsaLv9kEMH',
#  148: 'R_26nqwtkjA3Kiv6h',
#  149: 'R_2DMjv1AWbwHBuiv',
#  150: 'R_1q1U49NE2TnPlq2',
#  151: 'R_3k5jusWutxjfG31',
#  152: 'R_3CIYnwQTsAhPSbN',
#  153: 'R_2Vg5bqPZwkwHHBa',
#  154: 'R_3kyWmXAI1tOHq00',
#  155: 'R_vkLAexhj1QLknDj',
#  156: 'R_1rGHrE4AeR5OVtc',
#  157: 'R_3246INTEk1hGGZt',
#  158: 'R_2EskES6M2p6Opai',
#  159: 'R_1g72HUHOwnA1jKx',
#  160: 'R_yn1cNTcWmiuzCMN',
#  161: 'R_9SkVdLNADEuPedb',
#  162: 'R_1gA2C1ea7peyPEd',
#  163: 'R_eFB3dtl1ojJmk7L',
#  164: 'R_9QUcmMseiL82Tzb',
#  165: 'R_pF1ojzuWBJFkpix',
#  166: 'R_dg4mKjxapFjCEI9',
#  167: 'R_aXDWsVHl8E02orn',
#  168: 'R_3et3GmsRqgecein',
#  169: 'R_247yX84yrbT0iqx',
#  170: 'R_2zJ8wheXFgUtsp2',
#  171: 'R_2wNNYzW8Z7SWUZW',
#  172: 'R_2ClTArPS96xhfHO',
#  173: 'R_12AtjOkKwuBsz87',
#  174: 'R_1hygt8O4ZUrRDeZ',
#  175: 'R_1kMRgKR34y1nRtI',
#  176: 'R_1rw8yKhSA3W9qXC',
#  177: 'R_2f8uW5FB7wgfYzX',
#  178: 'R_2bI8608QhIEuTYk',
#  179: 'R_bIRIZknxYfaajC1',
#  180: 'R_2SkpVgUK9mkSGWk',
#  181: 'R_3ReJor4p8tOuxPQ',
#  182: 'R_1Lk63peQdqZUCJx',
#  183: 'R_2fK8RPzSklf70Rb',
#  184: 'R_yQpXk9lB6Ln0grn',
#  185: 'R_30nI9buMjsI2mYF',
#  186: 'R_1rrewaxox6bmxCA',
#  187: 'R_1dayMhoh6zi7aU3',
#  188: 'R_0iIREyvpIFthqTf',
#  189: 'R_2AQLbx6EHp1xaXp',
#  190: 'R_BPzP5ealnnpoM25',
#  191: 'R_yHAT8DRhd86jGy5',
#  192: 'R_3Gf8h8XZ9h8VUO8',
#  193: 'R_2aJNiKhqNUXYjWd',
#  194: 'R_qx5gJRe4vSHu46J',
#  195: 'R_2s09pWM8SK7HsZJ',
#  196: 'R_3lFTmZJTDYJlc3L',
#  197: 'R_1JWN4oX1MX0krvM',
#  198: 'R_2qxDTl6fT538Jew',
#  199: 'R_3Kx4ROZZ7oLVcZ6',
#  200: 'R_29gnVLakUS555Qe',
#  201: 'R_bC7pmtkBYlCnUBj',
#  202: 'R_2rVmv5HPUpLzYpX',
#  203: 'R_24u8DkD6UYYxNZm',
#  204: 'R_33fe3hIj5qLKPlE',
#  205: 'R_1gLsYUklpOtSKKi',
#  206: 'R_24CuCN2XZ6JcYTu',
#  207: 'R_3RyjTyyiyoNw3HZ',
#  208: 'R_24Pp5aw5bWHVAGY',
#  209: 'R_3DqEWTBPgI8hbWA',
#  210: 'R_2pQqZemJmfJIvsl',
#  211: 'R_3MGbwN6Tg3IAFmw',
#  212: 'R_24BIXqMevrQLLbo',
#  213: 'R_qWy204GsgITNWFP',
#  214: 'R_3kfRL33HVw4D3DH',
#  215: 'R_1FS2s0R1waCQFfm',
#  216: 'R_3PRVsQ2IM4O8GBk',
#  217: 'R_1qUP0iCEfaCcS0S',
#  218: 'R_2cctD3EF1SeggEt',
#  219: 'R_3HTuSsnhAuH5Z4w',
#  220: 'R_xDiDKabi0GlJWEN',
#  221: 'R_2vYs8LMzRf7NLH3',
#  222: 'R_RWjIAHokw6DoelP',
#  223: 'R_21AEix5yS8P4Tio',
#  224: 'R_RCgfXXZOdTDxiKZ',
#  225: 'R_1OxWqtdZ0U7qZvx',
#  226: 'R_yZUwFhSuYYYb8e5',
#  227: 'R_337MxPPecAsC8Vc',
#  228: 'R_2rGtHyVsai8yw2A',
#  229: 'R_uyut5hFckkwckZX',
#  230: 'R_vxekwlOshl0JqjT',
#  231: 'R_PtBRSswVJ2xzrHz',
#  232: 'R_1IHm6ceKHr2u8oe',
#  233: 'R_2EbGVv78GYWe8rD',
#  234: 'R_2RWF6u4bL8rUUtl',
#  235: 'R_2fDJaNZSxuJvWc3',
#  236: 'R_shTGdWg3lCPKKch',
#  237: 'R_3P7vK1lWaeROXGv',
#  238: 'R_3EDSWxtKKyy99Vx',
#  239: 'R_YVPJrd4DWlijxRL',
#  240: 'R_2aqtyW3yugm7RxR',
#  241: 'R_10MWVyxwJ8R3hRc',
#  242: 'R_3hhanSyNTxC8Q2H',
#  243: 'R_1mz8sVuiyAL69dF',
#  244: 'R_3n7BLYhrPW9bSHA',
#  245: 'R_2P6kKu81mQNlJAN',
#  246: 'R_2Y9OBDAZpsKCy7G',
#  247: 'R_2QJNKJaWmqq6kwF',
#  248: 'R_2Pu5gTSZXo9VrtA',
#  249: 'R_3k4IeCopUG6h3em',
#  250: 'R_1OCw2n4rqih1g02',
#  251: 'R_3nDHr6bj0yqE17v',
#  252: 'R_sZ204t0JVksFBWp',
#  253: 'R_3qIOg5aK9dc7mhO',
#  254: 'R_1gnJA6HJK9Mik5j',
#  255: 'R_Q4cRoojDz29Gjol',
#  256: 'R_2TRezdQ8Bk8tkXw',
#  257: 'R_puaqTqlIiWUWXYd',
#  258: 'R_3JIMUPHJIQizZYP',
#  259: 'R_2B8IWAGu0YCZMZo',
#  260: 'R_2wFC3R0mTAZ3VM9',
#  261: 'R_2rI8DTOVaCAM9qd',
#  262: 'R_3GiEcSF3AtiErD0',
#  263: 'R_3p5bMuwpcWpR6NB',
#  264: 'R_Drd21GjNvWO58dP',
#  265: 'R_1duaV1LE9TOnzYB',
#  266: 'R_2cpx51ZR3zG8iqc',
#  267: 'R_3n2Vz7kaTRYcaVE',
#  268: 'R_1FKyHE6KlUtyjq6',
#  269: 'R_3PdXjHl6DqMK7S3',
#  270: 'R_3P80ET5L9yQsOcv',
#  271: 'R_3CVGUsdtaa8bl87',
#  272: 'R_pGxRt1jpavVADlL',
#  273: 'R_6Yetv2N61B1KEDv',
#  274: 'R_3Pbin7eZMDTYt0I',
#  275: 'R_3fpbi7oUC0Kb8dD',
#  276: 'R_1lgZneJ74vS8iBJ',
#  277: 'R_10HqCvTzP3CnCpd',
#  278: 'R_1doYqp2AI2rAhCF',
#  279: 'R_6hwz9SROEejjWMh',
#  280: 'R_1ihtGZrYcG8hSAR',
#  281: 'R_3fIWXECaKITXKB6',
#  282: 'R_2f208tlQSA2Lfis',
#  283: 'R_ZfwzXLmLpVWxGPT',
#  284: 'R_3q9EgrF2vcK8hOR',
#  285: 'R_1gIyU2UsnpUycCy',
#  286: 'R_2dGF653Iti2venM',
#  287: 'R_3faxKFq4qPWOY5r',
#  288: 'R_3E9Lr7XeQ4nXDpT',
#  289: 'R_29mpbdaxrNaSdAL',
#  290: 'R_1FqC4S9thqlpYZX',
#  291: 'R_3GjRnE4O0Xj6vae',
#  292: 'R_3ELpjmZJmzGQ6BO',
#  293: 'R_2V9kzYLN7JJJF8a',
#  294: 'R_1prkDzQCumNbhka',
#  295: 'R_R2XhPi7vVPNmp5n',
#  296: 'R_31dssHhdeHJnl12',
#  297: 'R_d5aRgKeMTlXFHhv',
#  298: 'R_33sxL6AFD1hiyiP',
#  299: 'R_1lftdzqOK0n0Kku',
#  300: 'R_1itxF4sqEABXx4y',
#  301: 'R_331NjdowNGuaBuS',
#  302: 'R_beypsisBHj7bGZb',
#  303: 'R_3RelQS9OGxZS7zc',
#  304: 'R_T5dhj9eWIIL1Yl3',
#  305: 'R_2dWmy13MqfJDWjC',
#  306: 'R_9oib22Jcbxdouyd',
#  307: 'R_2f2GRToXU8urzQA',
#  308: 'R_2dhzqLemzauLUXW',
#  309: 'R_1gtnb6hmuZ6ICEA',
#  310: 'R_yvDQMipyaMhuCdj',
#  311: 'R_TpFCerZ2nkJL82Z',
#  312: 'R_2c0LkQ70jlqwGJL',
#  313: 'R_2Yc6SfJ4pBU0LhE',
#  314: 'R_2c5ZVexmkc3MFak',
#  315: 'R_C7WGekmER5CG0YV',
#  316: 'R_2YqXhorGC1irxBG',
#  317: 'R_3HiPsiNbHdmGIW1',
#  318: 'R_XYdURz2zoQMkxiN',
#  319: 'R_1CCpln5Rc9d2Yh5',
#  320: 'R_cXPmXIZEyd7bmlb',
#  321: 'R_UAqTUK0sqS2U1lT',
#  322: 'R_1CrsMtyoU88EXRo',
#  323: 'R_BRhubkZNQ6bulrj',
#  324: 'R_2bOCyi4t5oAPast',
#  325: 'R_3NTV3Rk7gwHB9RV',
#  326: 'R_PGrLF42oxirSYDf',
#  327: 'R_3Rkn2CaRBkbibiG',
#  328: 'R_20Pc79fJjvPd2K0',
#  329: 'R_0rdN6bP5Altat2x',
#  330: 'R_2431TKGby5WF4qL',
#  331: 'R_3oSHnXfYI1esO1A',
#  332: 'R_SBM13h7kzm1xBV7',
#  333: 'R_3m4z2NGu5SwFVMs',
#  334: 'R_2VKEwbbwglRjTqR',
#  335: 'R_dmAo18nipoUo01P',
#  336: 'R_sqbzciQIj7rbK6d',
#  337: 'R_1TVp2jaeftUPGUN',
#  338: 'R_DNADBrpffsXSdDb',
#  339: 'R_1gjsNmko8NYrXdf',
#  340: 'R_2usvWTFpHaVlKkm',
#  341: 'R_TiPdho1WDmeWzsd',
#  342: 'R_2v21LP9PDH3gNoU',
#  343: 'R_23fTZqfko2DWrZt',
#  344: 'R_3Kr7Z3fVypCkZCx',
#  345: 'R_1irrsqBRyVmbHSw',
#  346: 'R_3MxJQIBvL7lYmE8',
#  347: 'R_78TvEJjwcngMCC5',
#  348: 'R_3p3AGwwH3HQ2E2U',
#  349: 'R_xmW0N6ZVQaGjmZb',
#  350: 'R_3iD4mjQ5GUBXsLX',
#  351: 'R_UiM8evdZca77XJD',
#  352: 'R_3PzgeEK03z4fjSD',
#  353: 'R_elYFFjHSTJ3r8Vb',
#  354: 'R_qxcY7eGOLGaYqw9',
#  355: 'R_szq7dD8BqblZ1Xr',
#  356: 'R_1etaPWIEX3vjOSQ',
#  357: 'R_3FRLrjkcZAvrsXc',
#  358: 'R_2tb9E1KaESEk4eH',
#  359: 'R_31MZN2vnt37uHwx',
#  360: 'R_3D5OoaHb1uSLTwP',
#  361: 'R_3KAVlPOgwRlk9FW',
#  362: 'R_3PBlRURkU9PnKdT',
#  363: 'R_2CHQHhcbrNp8BpN',
#  364: 'R_ZIEHldRJctpAunn',
#  365: 'R_1K3YmDRsPPcmH12',
#  366: 'R_3JwxJex5UA9c9lr',
#  367: 'R_1dnxAEYI8mzccRc',
#  368: 'R_2xWsOt5QnlWZ5Sa',
#  369: 'R_afprOR5Hpfs9YBP',
#  370: 'R_1M3xst3cjJw8B75',
#  371: 'R_3m3GT6lEaYhEmpK',
#  372: 'R_3qI65LFWrrsFTN4',
#  373: 'R_1pQc7pMeZM8DkpQ',
#  374: 'R_2VBGtv8BBKaiTxf',
#  375: 'R_2y2BnmXIpQlx8a2',
#  376: 'R_1ODLX5ydj3h6eCU',
#  377: 'R_3VpulZ3VHqa5HKF',
#  378: 'R_3FW3mUrZQFdUDMZ',
#  379: 'R_1MMSIYGeIXxD9hC',
#  380: 'R_8AfGyVB7A7KWWZj',
#  381: 'R_2rITmAqupsmBlEm',
#  382: 'R_3fxByuAvCeKbQxO',
#  383: 'R_sXXjYWUyizJkXSx',
#  384: 'R_p9JbFNjxbAWOA4p',
#  385: 'R_3ezc3XwFDfEaXdl',
#  386: 'R_3si5PTYvVhQ6EgQ',
#  387: 'R_C2HKSccnR8362M9',
#  388: 'R_2Ytuaypv8BwC8uU',
#  389: 'R_5dQGu6zFWvmL2i5',
#  390: 'R_1f33q09k9LvUyFZ',
#  391: 'R_2D6oXP9D502HhUO',
#  392: 'R_tE5vBhIT7fWXEYx',
#  393: 'R_1GJ3Gf7jynLmnQ8',
#  394: 'R_33v8AIPRaybvxyA',
#  395: 'R_sdT4edrfKuZdA0V',
#  396: 'R_sNefZ2cS6vsSEcV',
#  397: 'R_1g2fuMu8AyKzAwp',
#  398: 'R_2QEAEbF1PMitn8s',
#  399: 'R_zYlAOKMo3PGH0w9',
#  400: 'R_1jUGuPqDo1mmhkw',
#  401: 'R_TuXrN7K9MU60NfH',
#  402: 'R_3qIJBHysYzX7dZ8',
#  403: 'R_w04d6o0WUx3t8BP',
#  404: 'R_3I4ARcRh2jYL8sW',
#  405: 'R_3ewxXXE35ZGAlV6',
#  406: 'R_XvTa3GM51yxs2Mp',
#  407: 'R_1eJY3HSRRwHb8dM',
#  408: 'R_2b2ZnVVSalzLcAT',
#  409: 'R_1F9ZqNGXhGWybsL',
#  410: 'R_1gSV2K0JZYivvUq',
#  411: 'R_30vOgVBVhd5sKnM',
#  412: 'R_264mcZwZJKMmZsm',
#  413: 'R_3qR8I69QvnBJul6',
#  414: 'R_28Hx5wAoDBbsY6F',
#  415: 'R_2xyN6Jg30kcY8Zq',
#  416: 'R_OOOdJ9PpboAPnSp',
#  417: 'R_3JCKHPxrm3blrAR',
#  418: 'R_11jXdp3rYf4Mkcv',
#  419: 'R_3h4j0z7YgVkobFA',
#  420: 'R_w5UyiC3JF89PNZL',
#  421: 'R_3iqdgZp8Sm71hjB',
#  422: 'R_YW8obmkRjjyHzC9',
#  423: 'R_3ekoYtT5y8FrjDE',
#  424: 'R_1eDelLJ155MaXVk',
#  425: 'R_1Nlaetv4Xpwfn1m',
#  426: 'R_dhxNRvn0W2VuDsJ',
#  427: 'R_3no5gfxbsLn1tix',
#  428: 'R_sOwOFOSXbmLreaR',
#  429: 'R_1ouRhDFRzcREL8i',
#  430: 'R_1pxI0z0Ufs2PSsl',
#  431: 'R_3k7nEXsKJy0laVT',
#  432: 'R_XM8cGAZHwDra4ql',
#  433: 'R_1yLUFjLQ9xYh7Nv',
#  434: 'R_1mCMi5IopUWT2hD',
#  435: 'R_3EGs6zeFZEQiVLq',
#  436: 'R_3mgg7JZhizGxXIR',
#  437: 'R_22Y0MXvV15eUdCU',
#  438: 'R_3FJqk44Yjwk8Iqs',
#  439: 'R_2uR1WmVXckbLfA7',
#  440: 'R_3CIYmTiKfc54UnM',
#  441: 'R_2YVpmFAJLIoa7Pf',
#  442: 'R_10ViVTPZShyJKhn',
#  443: 'R_DUjUFrSvxkhG6qd',
#  444: 'R_2dSfwuJuwxwA9d0',
#  445: 'R_22lxlhuN8Ey2QeB',
#  446: 'R_5ouOa33sITanGUN',
#  447: 'R_tPsLG8zd5VW52lX',
#  448: 'R_1gHi9oYZ8HPDLM1',
#  449: 'R_3CZZuqpQrlz0b1u',
#  450: 'R_3LZsrKIRL7Av93N',
#  451: 'R_xDc2ppuAnM4A0vf',
#  452: 'R_rjPfu5ux8Li6f2F',
#  453: 'R_3NzeZzXK4oaDq5s',
#  454: 'R_2Si4VGihyFz7Y6V',
#  455: 'R_1rrbpbIFzsjFmi8',
#  456: 'R_AumgWa6vNQuF8Pv',
#  457: 'R_2yeDCbGccxEo5HB',
#  458: 'R_aeN23XaXeiSFq4V',
#  459: 'R_vC56GzLk6WYapXj',
#  460: 'R_3esqif9DND0BvlP',
#  461: 'R_3lzDrHje9MH7dEY',
#  462: 'R_1OjYUlAUW8wxq6F',
#  463: 'R_12tjM08FxhX9zA8',
#  464: 'R_2qg74qEE5BZexfC',
#  465: 'R_27apjgoY2L2KIOn',
#  466: 'R_1P6RntyUKpVnGCe',
#  467: 'R_1j97coM0uhz5umw',
#  468: 'R_Wwjyy7NQe69vzax',
#  469: 'R_333HXJXrWtCuWxi',
#  470: 'R_2D1wMg4BGC1Si09',
#  471: 'R_3jeABW5jJnAftB8',
#  472: 'R_1loeTToccQsJISj',
#  473: 'R_2D2KP6HOSU7CcQe',
#  474: 'R_3qmue8vWUbSWMuw',
#  475: 'R_1pQlYO62MzqBVJn',
#  476: 'R_2V4GGup4jX6YSLh',
#  477: 'R_24cIpNZXSlpn2Lt',
#  478: 'R_3U8btRYAldDTRdv',
#  479: 'R_2zBKNHSFYdsoJX2',
#  480: 'R_2rZ1m9itlIJL7I0',
#  481: 'R_1pS9dY9HZTyHWAB',
#  482: 'R_3m80TH5d1hU9Qp9',
#  483: 'R_1gu42mR4MGX0ykp',
#  484: 'R_AB5EmgZmdeiU6Ln',
#  485: 'R_cTvNIiRVSh4YsUN',
#  486: 'R_vCVdgVJn0QujPup',
#  487: 'R_3G6t4Bd1NUPNqHP',
#  488: 'R_20MwkVvZ51MXn9Y',
#  489: 'R_4O9MpEXmM2cBqff',
#  490: 'R_31mjlrWU4Ki7S3e',
#  491: 'R_3OcCqXbWU47npeH',
#  492: 'R_29oxKaKybevwqk3',
#  493: 'R_2wt61hHMVfHw73A',
#  494: 'R_3kzuWwJmo4vtuRz',
#  495: 'R_3n5VPd2aA1julNr',
#  496: 'R_6A5398OUoTO4xjP',
#  497: 'R_UZ1XNTVGIJFZzwt',
#  498: 'R_A7DURVEmzVHmnqF',
#  499: 'R_3q8Yc0Q5gmWPCjN',
#  500: 'R_2wEu7suPYlbTFzR',
#  501: 'R_eOJjJuKb0HiYThn',
#  502: 'R_WrFuNkz6mtVM1mF',
#  503: 'R_23fctseOQzdho8A',
#  504: 'R_31c4bkaoC9oFDvy',
#  505: 'R_2q4r0RxOeecndFE',
#  506: 'R_2VQIMTeuv64ZRBO',
#  507: 'R_1BWnt16crNsOMlO',
#  508: 'R_3dQy70InlDe4mf4',
#  509: 'R_vTYnqkeMbLxWGQh',
#  510: 'R_Tj8qurphwTEGlq1',
#  511: 'R_2zYeahm7uSIvaw1',
#  512: 'R_324Oz36PFhCB1d8',
#  513: 'R_2Va79uuR8i01Ks7',
#  514: 'R_1Q3XRdeZY67Xjmq',
#  515: 'R_31NRGO3uf3DuiMx',
#  516: 'R_d0tlwpZR45ArZSx',
#  517: 'R_21acEC4BYGcYuOk',
#  518: 'R_2zHNh893WnMNhfo',
#  519: 'R_SOANdp9Q0THBKtb',
#  520: 'R_27rMLm5gBTPREOA',
#  521: 'R_2vdeAnvwaeFAHHT',
#  522: 'R_UcPgcAIOR577UYN',
#  523: 'R_1QGYAYbNhtQJ2Hr',
#  524: 'R_2qymCxEhO5wj1PS',
#  525: 'R_1gCPmmaww0Tj7fx',
#  526: 'R_3Rrduwe5Vhu9Yzd',
#  527: 'R_3s0ldVvCOQ4W32X',
#  528: 'R_2pJnCINKIXGlKG1',
#  529: 'R_2CUIr9FzPnwiUXV',
#  530: 'R_271lXQb3BMuLIXG',
#  531: 'R_3CVma0KNE7BIJ1s',
#  532: 'R_29nvo6n4Fs1U06X',
#  533: 'R_1pnh5a1HstQwLq3',
#  534: 'R_3oOaZAtnfK9YdwE',
#  535: 'R_0IM30kdwHtw6DIZ',
#  536: 'R_bCMbH8Z9RZZxcyt',
#  537: 'R_ODcGNUIVrh7u9Md',
#  538: 'R_3OfDY3LpFwlUi2U',
#  539: 'R_1LpOe8EtyDvnQi1',
#  540: 'R_22y4erc7aDeKsaW',
#  541: 'R_afuJRokuDQc6qdj',
#  542: 'R_4JHwhsAY3UAmHLj',
#  543: 'R_1i4G6ibrr0McRuq',
#  544: 'R_1CJvz7qtt78Or5b',
#  545: 'R_3DdpZrzdbcWfFkx',
#  546: 'R_71BJAD7sk8ovxPb',
#  547: 'R_3O7hlyZWuLVerQB',
#  548: 'R_2ydrD21EU8tQkI3',
#  549: 'R_1l4tuKkFtbiHUxR',
#  550: 'R_1QfP0XLOgeNXfwX',
#  551: 'R_1dEvzIhnkYpwUPv',
#  552: 'R_3CN5F43xJQJe7nD',
#  553: 'R_3ExT0w5OgO8v2eb',
#  554: 'R_31HSh2SFE1F5VzC',
#  555: 'R_cGdm8M6jpcp5H4B',
#  556: 'R_33se6usaqfdgUBH',
#  557: 'R_2pRAZnDihb3nZHX',
#  558: 'R_1HjefsPZFanCmKg',
#  559: 'R_bPhSn9zKuA9d94J',
#  560: 'R_1hLlpkDl5uPq1ig',
#  561: 'R_BGw6EjBF9AtkSxH',
#  562: 'R_2QnR2iFfFQcNuN2',
#  563: 'R_26c1yUQHjvU2Q2U',
#  564: 'R_ugl8IIlHavg4nxn',
#  565: 'R_1dLhzRLrLQahdcu',
#  566: 'R_3oA53RLFMm1tDdu',
#  567: 'R_1OiTA388VUshmQt',
#  568: 'R_1HC5bg3zcLvxQBz',
#  569: 'R_9U2MHIQx5zZzgNX',
#  570: 'R_1QEeGK6Po5PpNZv',
#  571: 'R_4VNW993KgEpI1y1',
#  572: 'R_3PZYJu0ANCeuGca',
#  573: 'R_1GPo4eaaoZ0slSh',
#  574: 'R_ZgY60EB7a6aeqiZ',
#  575: 'R_214yDjSlcvaBcR4',
#  576: 'R_3qQmEyFFe81RetG',
#  577: 'R_2TyPwj0kg1KpyJf',
#  578: 'R_1et3d1K62RgoeK9',
#  579: 'R_9XIpbbIuok6VDYR',
#  580: 'R_AEyZKPDrXCtLLfX',
#  581: 'R_3suFEngPi8DiVej',
#  582: 'R_pDGjnqHpuWH9GUh',
#  583: 'R_2TMYoTMHgYadHhg',
#  584: 'R_RaaMCN4WpO9dvIB',
#  585: 'R_plUnCeVM4aprPOh',
#  586: 'R_3QDYIzai00XwLOm',
#  587: 'R_3J983CnSjQiC057',
#  588: 'R_31aQ9gEKRlObl5M',
#  589: 'R_1dAgAo796BTaJOk',
#  590: 'R_3Leji03PvJgFBms',
#  591: 'R_21hMIYfzjqH4nd0',
#  592: 'R_1qVe4raXsGHYi8B',
#  593: 'R_tGrYP3X81oFiiwF',
#  594: 'R_2coVUnItFrWEjWH',
#  595: 'R_4ObCyWN2ESTk75f',
#  596: 'R_1JFN5TwnHZ1Ac6w',
#  597: 'R_1guNDSt2aSonFi6',
#  598: 'R_2vchewiQt6q9JkW',
#  599: 'R_3TXPvROivJUNigN',
#  600: 'R_wM17j7q3vJWZqQp',
#  601: 'R_2OVaBJXXddnSBIf',
#  602: 'R_3Mbal4eqiOA7nbD',
#  603: 'R_2S1Wa1KKOxdqCH2',
#  604: 'R_poWOFzFYjJp3lqV',
#  605: 'R_e9Z10idcaeO1oWJ',
#  606: 'R_3oMbQpQNOMSJXRC',
#  607: 'R_tMrpeK7LgnpgMoN',
#  608: 'R_27qvwLL6YgX7nmI',
#  609: 'R_3LcLYUWcZ9sL6eC',
#  610: 'R_12yF3DTKeRV5QRI',
#  611: 'R_1odx6wtu1MrD36I',
#  612: 'R_2OJFLjjz53Q8pl6',
#  613: 'R_O3R80P2RYjB0UcV',
#  614: 'R_2SqRcTDhPqlqP5Z',
#  615: 'R_1LZ3E31stle4CtA',
#  616: 'R_3h0ydzPbSkpXzp6',
#  617: 'R_28FI5p432aPLq2O',
#  618: 'R_3qX2OHRaSsk08Ne',
#  619: 'R_2fD3Kz06l0rBQbq',
#  620: 'R_O8YFC4PjFoJyrap',
#  621: 'R_1kNDAVXwIbd7rxK',
#  622: 'R_W1nlmKnHz20Ob3r',
#  623: 'R_UH0lx5MPq16cutj',
#  624: 'R_3kLqLMRV5wmwRmk',
#  625: 'R_1JW4VLbcsBpXoxw',
#  626: 'R_3KHJy3aDdLc2wWv',
#  627: 'R_By9R3WWznI3X01r',
#  628: 'R_skeTaMPTXpGwOAN',
#  629: 'R_31RfrRk2RhASQq4',
#  630: 'R_3Pi8tZLPuhAlc4n',
#  631: 'R_sHfKve6E5dHext7',
#  632: 'R_3hGvmKftj1sMOtK',
#  633: 'R_2uUn30qGeRaqirA',
#  634: 'R_1E4mWujrgPWMTmS',
#  635: 'R_1pSdKlBAp3xuFK0',
#  636: 'R_2TSMUvlKV8fnidY',
#  637: 'R_OvBakwyizb6i5d7',
#  638: 'R_338XC2MUCLjwg8i',
#  639: 'R_3ESWXOaUyeQEq17',
#  640: 'R_BsRDA9F8NXGRWUx',
#  641: 'R_6PuFPppbaoCafFT',
#  642: 'R_1d3LVCWMkTZQDdF',
#  643: 'R_3qfckfab5yzIwhZ',
#  644: 'R_3gRenOW1gfXvoji',
#  645: 'R_1HcQWklprOSXvMA',
#  646: 'R_2dp8FXH12VvQdHP',
#  647: 'R_3fYH1lLIejLy2ME',
#  648: 'R_3dQi4ZmdHtV5mOi',
#  649: 'R_2bQsNPugROzgqpC',
#  650: 'R_2xCTzUxIkXeui7c',
#  651: 'R_12fBneHOBYNHmBa',
#  652: 'R_2ara7JrfAhJ8KL0',
#  653: 'R_ptN3VDtNzTMnE0F',
#  654: 'R_rey6TCITsgBzeqR',
#  655: 'R_2CNQIvoxFgBjZoV',
#  656: 'R_25vwnqZQHs8KOi1',
#  657: 'R_3CD8xhELY6ljRag',
#  658: 'R_xsXbhRnc1fRcaVH',
#  659: 'R_AEEMhtm2da2nFL3',
#  660: 'R_1mf1xShM3I9Qsmm',
#  661: 'R_1rHXcvSBNAn4rTv',
#  662: 'R_1N38C6sdUjGbqBq',
#  663: 'R_3fwKeqvjtJVjycu',
#  664: 'R_1FG4CiXKJiLJuBR',
#  665: 'R_1ez4S4rLFdTqpem',
#  666: 'R_1MNdoYoj0sN2MlY',
#  667: 'R_3qvxVnuOXt1Dmxz',
#  668: 'R_214GoHZk5dgMR3X',
#  669: 'R_OsaELTaOH3SoHIt',
#  670: 'R_C9Q59XRBKQUgXFn',
#  671: 'R_aY4P0l5D0z5NZLP',
#  672: 'R_2xQM06KaQHfdFZB',
#  673: 'R_2Qujsn8vbH2TsQR',
#  674: 'R_xxd4hp1F9Lzoxzz',
#  675: 'R_2wvKIuSpTpBCgBf',
#  676: 'R_1IMjmySR9YhxjBk',
#  677: 'R_1LMrbgvGGw5heGQ',
#  678: 'R_23UXoxB6eugEKJd',
#  679: 'R_3hc0j7sfciBmhAt',
#  680: 'R_T65ekBBheg4Udbj',
#  681: 'R_2qeBYa5lg3OhQrF',
#  682: 'R_2z6he9wp4c0Mpis',
#  683: 'R_0V5vMZ2TNuiRqr7',
#  684: 'R_bxdFJsmXs8A5czL',
#  685: 'R_1o6I2S7zwQ9oAEY',
#  686: 'R_1Qynggc3R4avAbW',
#  687: 'R_3QDf4iaAa56WcZE',
#  688: 'R_psHFVqFTYZBFS2R',
#  689: 'R_2Sltw1kH15FVW9J',
#  690: 'R_232j3CSj6Ccj3yf',
#  691: 'R_b1t27Ux6Ltsfsvn',
#  692: 'R_3RehDJqOexr5pD1',
#  693: 'R_1r8l7R24m0ndQnE',
#  694: 'R_0oM1mubG7kSBI5j',
#  695: 'R_3PsH9ozF53dIZVk',
#  696: 'R_2EzcTNcz07DV5Y5',
#  697: 'R_BrWIkPNW6xsB4ml',
#  698: 'R_3nctMhYIPXVEYyd',
#  699: 'R_26gsyzo7yI5JphM',
#  700: 'R_2tDSabm0Nrz2sfp',
#  701: 'R_3oFR0GU7nTyw9HB',
#  702: 'R_vo8Nk6htca3oSVr',
#  703: 'R_1mmYDBqAHnsIKDb',
#  704: 'R_PYBUthTjgBNiFmp',
#  705: 'R_5vAQKhiR1QPh0LD',
#  706: 'R_0OjW4iu95SqNnNv',
#  707: 'R_3iJ7VXPrHFyVa6L',
#  708: 'R_7aDOzU9XDUaGNBD',
#  709: 'R_PvoRigMy9GWNLnb',
#  710: 'R_3ltYMLbCR0uyuCk',
#  711: 'R_3OjfmSksXtVXFG7',
#  712: 'R_247ERXtWmPmmLbX',
#  713: 'R_UzqnpDWB9ekR6Eh',
#  714: 'R_1LuoeDmEHtDNF9f',
#  715: 'R_oXMmsLxjZdU4PxD',
#  716: 'R_UhGBgdLzzYr58cx',
#  717: 'R_1CwHOQCz8lgYC3z',
#  718: 'R_O0A0G6mZvQ2Sqk1',
#  719: 'R_SPK98FIrKiqc4CJ',
#  720: 'R_1l4E0EoyPPRDUHu',
#  721: 'R_3fktK0Mr0DBTIEn',
#  722: 'R_0B1wpzYwEJyRopH',
#  723: 'R_1IlNvDw1fku0ldx',
#  724: 'R_7WCERR8Df3ZbTOx',
#  725: 'R_3qfeX4wV3QyCbnf',
#  726: 'R_3JCMuNDyQkMRhfi',
#  727: 'R_e8nAAYaMRDjlVaV',
#  728: 'R_2atOvFyMM38QvoB',
#  729: 'R_2ZIA8gjyuTsHMBi',
#  730: 'R_5ceXpHy3e1wxRbr',
#  731: 'R_3D6zyo94Thp6uuA',
#  732: 'R_2zGBZUz7zRNGMwO',
#  733: 'R_33a6yc2Z8LiRkbW',
#  734: 'R_2V8sGZxR6JX3UNX',
#  735: 'R_2EjcdZHgIZr1HXJ',
#  736: 'R_31pmACihC88a6Yp',
#  737: 'R_x95MqKc59LCuPCx',
#  738: 'R_3PRYjwzd7BRwFFJ',
#  739: 'R_2t3WywOyYvxT3vc',
#  740: 'R_PZJV1o6N35qCzbH',
#  741: 'R_2Bg758iFDnWduz4',
#  742: 'R_2xW6MrDNZ5z3hzZ',
#  743: 'R_128UeniNy0MV8m3',
#  744: 'R_2rA6YuJlb4qHN04',
#  745: 'R_3MzB9GqOHOKDTPU',
#  746: 'R_phP4KQSPjbbQ2el',
#  747: 'R_3oNu8ANTl7JIzcs',
#  748: 'R_3h5Eu9LolUGWSdk',
#  749: 'R_BqZNwpu33FbdUpr',
#  750: 'R_2VkY9oQceNmVf8E',
#  751: 'R_2RNSUwxls2GoIhj',
#  752: 'R_2bISLmZYH5xPjuQ',
#  753: 'R_3htHwBmqL1P3Hvr',
#  754: 'R_3Eut5y8QCzAkFDr',
#  755: 'R_viSuzK6ebcSilNL',
#  756: 'R_PtfOYdSdM58geCB',
#  757: 'R_278UgboUPUZboYr',
#  758: 'R_1mgRO5VOvUSB5Mb',
#  759: 'R_3qdHVFrbMgQzQWX',
#  760: 'R_2zA7PqgMnRtRch0',
#  761: 'R_2fl2bbownBq7zcm',
#  762: 'R_2v6OHR9TXeMEJSP',
#  763: 'R_agTjV7Rf1V5Jqet',
#  764: 'R_2VEdgRYlnw5yco5',
#  765: 'R_2t9cUvKa4X8WKLQ',
#  766: 'R_1d6L5YzaH3M57XO',
#  767: 'R_27EBGEFi1DyziVN',
#  768: 'R_1K7Jhluw2kqvB13',
#  769: 'R_22SldHZUxrM8oht',
#  770: 'R_1oegnHjqdUnBF9Q',
#  771: 'R_3g8bwQ6WkZKD6uO',
#  772: 'R_3L7PSnN7tlE5FzW',
#  773: 'R_RDKokrIC0yh44zT',
#  774: 'R_8cqMtF7lmBAHU9r',
#  775: 'R_1LUtj7dzSNmZ7Gn',
#  776: 'R_2DYMicGyxbshFKW',
#  777: 'R_0TikC0y7wO1euNX',
#  778: 'R_2QDmCNZpspWhAZP',
#  779: 'R_3JbgBOfyEDa92mt',
#  780: 'R_1JF2bv4lpxes8GS',
#  781: 'R_DczDvdlnYAQsKCB',
#  782: 'R_1gOOg4fjapeoTdN',
#  783: 'R_2wi4JwILYeQheja',
#  784: 'R_Xj4UupfcpNTLOvf',
#  785: 'R_1yKWE2O5bMfs8gx',
#  786: 'R_svAEZ1vGS4B6797',
#  787: 'R_26l5unP6ToAwR9w',
#  788: 'R_1P0E1IQtUyneKLa',
#  789: 'R_2c8FAkUsY3g4xFE',
#  790: 'R_3ixMCsUoGIEbyLx',
#  791: 'R_1Ao6QqsWkavZIoF',
#  792: 'R_w5zanMJoiaUZkdz',
#  793: 'R_2tnc8pm29XutyXd',
#  794: 'R_daLprHwX6zDi6R3',
#  795: 'R_30cJnLgMClvn9j2',
#  796: 'R_2fm9GpK8VHtjGPW',
#  797: 'R_3kOph4Pbp85bxvX',
#  798: 'R_3HYppclVomQ1U0x',
#  799: 'R_22kTAmp831CRCt3',
#  800: 'R_DM3qrgq4BnMOzkZ',
#  801: 'R_SPnJPrSBAIHkRDr',
#  802: 'R_UR5hd39iWJVOVnr',
#  803: 'R_1pAnOk9qESNyECU',
#  804: 'R_2905KepZD5aPnHf',
#  805: 'R_cZUzSxyc2v4sexX',
#  806: 'R_pB5bEbdRNHFh53X',
#  807: 'R_25yYH3YI1G0qX0U',
#  808: 'R_2ZTyHY6KjQhXCzs',
#  809: 'R_3DihSpCJbzLLuEm',
#  810: 'R_1rDlIph68HBQKKf',
#  811: 'R_BSpXiuxQGa4BJ9T',
#  812: 'R_2eOtfsNXMyyx43x',
#  813: 'R_1li1v9kxpMgAkzb',
#  814: 'R_WjRbrusctR07CXD',
#  815: 'R_3090pIUtSt1CXPN',
#  816: 'R_2R9DuFWVO9ahI2U',
#  817: 'R_1DNG70WFkwGfH74',
#  818: 'R_1Iod3GtU6pk5xa5',
#  819: 'R_3Lc2XaaymOUwcYT',
#  820: 'R_2aX2x8d3LCdzUyt',
#  821: 'R_10C2a0cuZdYGdSB',
#  822: 'R_32WMYa0HufIPSnC',
#  823: 'R_2rOBeSyZxGdtrHe',
#  824: 'R_3dMS0biEIiUXclX',
#  825: 'R_1jpM8jj1oDuaDe3',
#  826: 'R_3koLhzC8bzjJxzC',
#  827: 'R_3qJqlTwFvFQDb5B',
#  828: 'R_2xE1o1J7Fc4un8d',
#  829: 'R_1JEnnAglvBnu9FO',
#  830: 'R_PO6oqdPVCPnsWCB',
#  831: 'R_28UKKLw0fvc1Yn8',
#  832: 'R_2SH6xdfuTQD8hE0',
#  833: 'R_27PbX0AyiKiqMAD',
#  834: 'R_80NgH1eHXD6DbYR',
#  835: 'R_25QQQ16LEjUBIyh',
#  836: 'R_3n96lzfbMGQf9bH',
#  837: 'R_25yzKvwrOPP2g3e',
#  838: 'R_3j7Zcj1HwBIPwnh',
#  839: 'R_3oHIQSneTWqoqg7',
#  840: 'R_2RV86oZxMwZIi2s',
#  841: 'R_1KcC4rNsGdgz78t',
#  842: 'R_PzKIWdL6XInMjwR',
#  843: 'R_1FL1sl2bQ9EO7Kv',
#  844: 'R_1IGVHB7JYNfu39K',
#  845: 'R_u1D7i9LDCcKc5Tb',
#  846: 'R_2rx2QE3ZuKF1Ley',
#  847: 'R_2sYoANdkeH6pmGo',
#  848: 'R_1oGUXGL7lOND2oZ',
#  849: 'R_3O69qS9dmIGLZhL',
#  850: 'R_3k7AQ5R8Y8IXooj',
#  851: 'R_2VJavesQbJEPn1l',
#  852: 'R_2Tv1RL7UCM1LAz9',
#  853: 'R_1dGkte1GBdZ11rI',
#  854: 'R_1dFZXV7Kuxkqbal',
#  855: 'R_D2FMequApyY5FOp',
#  856: 'R_1OAKoZOGTEVGR78',
#  857: 'R_YWHN7JpMkUnXtL3',
#  858: 'R_ZleX6mnkJsQUwUx',
#  859: 'R_NVbRS571VwykFiN',
#  860: 'R_3MGP9toO9FB1YSy',
#  861: 'R_3O99eIOG41rQJxK',
#  862: 'R_1ovUFTJMCw5mJfo',
#  863: 'R_1qgEHtFb9ebZ1rU',
#  864: 'R_3KDc7SPYw6fRlmI',
#  865: 'R_3Eioj5qWNhP1TTw',
#  866: 'R_3CI9LX2JSkBEBp9',
#  867: 'R_2y2yXfSUn9N1SYX',
#  868: 'R_ZDKl4AReezcPtMl',
#  869: 'R_3iC0Acog4I55hV5',
#  870: 'R_3njG0Fh9zg6pKIk',
#  871: 'R_12FjnISykgtwzz2',
#  872: 'R_PAnCNf9hluOm7bX',
#  873: 'R_2y2Fxo7bu49ZslO',
#  874: 'R_VKgZ5JNEhZrcYY9',
#  875: 'R_1i84GM8iaYxQpwr',
#  876: 'R_1r1igF8ovLOz7Kj',
#  877: 'R_1JKGdkPW3W2fNs3',
#  878: 'R_26fGqXC4kB0DHqQ',
#  879: 'R_33lpsRznpjdqENz',
#  880: 'R_cBxniCt7uDhFKZb',
#  881: 'R_3oAZRRiyrf5C62H',
#  882: 'R_2w76iu45e301mST',
#  883: 'R_2dXhuvt8nrKrqDy',
#  884: 'R_2qrCsfDnCvvm90a',
#  885: 'R_3P5FDlmVbdJ7Kn3',
#  886: 'R_3n10jFaBlKzMsTI',
#  887: 'R_2qkDogvajPsvMiV',
#  888: 'R_1IRBNnljNA7ZWtP',
#  889: 'R_3ErS29Wuo3PyqYf',
#  890: 'R_3MEfughIvUyK8kS',
#  891: 'R_T7TExBY3X6jfrIB',
#  892: 'R_1lhlqJjay8rBqMr',
#  893: 'R_BxJsUGaZsA4zBbb',
#  894: 'R_4YGienLNPq1zptf',
#  895: 'R_3rHPDld0UvSKgKO',
#  896: 'R_3FJ3gD6EtkynidO',
#  897: 'R_1rjMoj8W68IM5dN',
#  898: 'R_24CrFdmSrOPf7mU',
#  899: 'R_1dvnKHkfioWLyIJ',
#  900: 'R_41LB9vf2fqXVkIh',
#  901: 'R_1pxjdWvr8lmWnZ4',
#  902: 'R_3NVu5KGaIy6zKEl',
#  903: 'R_26l7kB9bRy8pVu4',
#  904: 'R_3fdtehgot1BxM0I',
#  905: 'R_3Ev7K4bkBGzFNde',
#  906: 'R_1kFdH0kHagbRseK',
#  907: 'R_2CdoODpckOeeiro',
#  908: 'R_27r3LvxoducJcSU',
#  909: 'R_2uVvqfO181P4rWW',
#  910: 'R_3hAZ83NIwhy45TD',
#  911: 'R_z0tJoCXSnCKOio9',
#  912: 'R_XhvOJxal0OT9mQp',
#  913: 'R_30wuDbCKF8c5Mce',
#  914: 'R_29hP1T6WMPW5NVu',
#  915: 'R_W69YHmRvrS4KjQZ',
#  916: 'R_31RE4FjyOWYjC0y',
#  917: 'R_21yAqy7pI8BneIG',
#  918: 'R_239yyz2OTi4NAfr',
#  919: 'R_296RosSwZ0GSdps',
#  920: 'R_28OR28JqgbrlwTI',
#  921: 'R_3mlZBsoY9hvx8EF',
#  922: 'R_2riparmrpuktoUc',
#  923: 'R_1gzKMCLQsTCpvaf',
#  924: 'R_3dDJmO3jN6ksjPR',
#  925: 'R_3O7V8xNaVWzrrBm',
#  926: 'R_3Migpp8MPQFJFtF',
#  927: 'R_YVQTnuia2Cjpd4t',
#  928: 'R_PMtRAnor62rE9JT',
#  929: 'R_2UVfNDr3TyrJCk7',
#  930: 'R_2ZQ7IvQB8D0HbBI',
#  931: 'R_25QoKAXDpKbnzZ2',
#  932: 'R_3KJI6Haw1JUlu2h',
#  933: 'R_27CjprURCF8LmWV',
#  934: 'R_1f3NrkWn97gKf1M',
#  935: 'R_1C9rmH5YrNSnCeo',
#  936: 'R_2rip0l21B5XfkBO',
#  937: 'R_1DOl3gFvSUmoHtY',
#  938: 'R_22XP4kuSW85fEi0',
#  939: 'R_Avq8Ji8PRc5MwZr',
#  940: 'R_1dzD1XZmsQMSTHJ',
#  941: 'R_3NLeAL9msAY2tq1',
#  942: 'R_1GEmZI86vyPcwFP',
#  943: 'R_3jdEpi2f88Fxt6X',
#  944: 'R_Zr79Mr6pe02REKR',
#  945: 'R_2bV1xC7UVTXajIb',
#  946: 'R_3HYqSnIa8wtkjWT',
#  947: 'R_ub5IwTtgKTVLAlj',
#  948: 'R_2zXP0ycT0gaUyH2',
#  949: 'R_26bT3baj4ZHvM8B',
#  950: 'R_1k2jzpSOxqJDLBz',
#  951: 'R_2sXVNdQck3jcF9X',
#  952: 'R_21glzPy8CmH6IDb',
#  953: 'R_dcVPn7uBtCDxa7L',
#  954: 'R_2f2IXMSKwHtE6lM',
#  955: 'R_3pcmZGMA0KKIUPw',
#  956: 'R_33x2HdaVNLYta8g',
#  957: 'R_3KOylYw88rI0goK',
#  958: 'R_2fDrCgehXjL9DXM',
#  959: 'R_1NCZVer8uosQHiE',
#  960: 'R_10wmR0f7sSyjfUU',
#  961: 'R_3qUvLm0EpZUmRYB',
#  962: 'R_1QMeiQhe9Ujj6xs',
#  963: 'R_1OYKtmmBMduEhcZ',
#  964: 'R_31i1z9lvzS6G8km',
#  965: 'R_9zRhQloW16ikRvr',
#  966: 'R_1CwiWdyzMy1fvSC',
#  967: 'R_z6WT50yJE3Bq1QR',
#  968: 'R_1hKDDE9ZrTGci6F',
#  969: 'R_2tKyRFCOxxSFJSH',
#  970: 'R_aas4BHO3SrACPJf',
#  971: 'R_1C4m1gMMM3ZSFQC',
#  972: 'R_2V86lRMHHrukNms',
#  973: 'R_1P6MRElPiDRu8Nw',
#  974: 'R_3emM9XK07tGm5ie',
#  975: 'R_2qqJKMpYlq0lYGy',
#  976: 'R_2fC0wsHz7skUkRv',
#  977: 'R_1riwgxAYWBCssTG',
#  978: 'R_2eXAoY3Dp6PRl1O',
#  979: 'R_26hGFYcKD7OfrgB',
#  980: 'R_2VPz8mGv8Hz7Gev',
#  981: 'R_2zNNvKCsqW95sEx',
#  982: 'R_1H8nypLiZmnR93l',
#  983: 'R_tYfqx07tfJWWaMV',
#  984: 'R_271pWSBQp3hSG6W',
#  985: 'R_2TGnatRTVTtXdZv',
#  986: 'R_5baK5NHyIqJsuhH',
#  987: 'R_PHQXFBJHDYnf8rf',
#  988: 'R_cCLtNOORJF04tuV',
#  989: 'R_3esqm8P1TGQiXWn',
#  990: 'R_3MrJK05ckHVPoFr',
#  991: 'R_Y5BucjUgKLYVCSJ',
#  992: 'R_2SuZQtCZXV2yEiM',
#  993: 'R_2asLiXvTwKIEztv',
#  994: 'R_3PiZBN2lsKIntUc',
#  995: 'R_3p9KHEZ5gkRkGGX',
#  996: 'R_3XaabZdvfPlI66l',
#  997: 'R_2P103JxUBTLJsJL',
#  998: 'R_2qdxTpPf2ieuDyT',
#  999: 'R_WdLgJj0K9li87fP',
#  ...}

# %%
annotator2id["R_3fP575Tw6XFk2ZQ"]
# Out:
# 105
